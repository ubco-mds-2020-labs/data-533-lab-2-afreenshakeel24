# %%
from game.rps import rpsgame
from game.rps_fan import rpsgame_sheldon
import time

class Maingame():
    def __init__(self):
        self.models = ['Enter 0 to choose Traditional version', 'Enter 73 to choose Sheldon Cooper\'s version']
    def display(self): 
        print('You have to choose from: ') 
        for model in self.models:
            print('%s ' % model)
        time.sleep(2)
        i = input("Player chooses :")
        if i == '0':
            print("Loading Tradtional version...")
            time.sleep(3)
            rpsgame.rpsgame.game_rps(self)
        elif i == '73':
            print("Loading Sheldon's version...")
            time.sleep(3)
            rpsgame_sheldon.rpsgame_sheldon.game_rps_sheldon(self)
        else: 
            print("YOU HAD ONE TINY JOB \n")

# %%
a1 = Maingame()
a1.display()
# Out:
# You have to choose from:
# Enter 0 to choose Traditional version
# Enter 73 to choose Sheldon Cooper's version
# Player chooses : 73
# Loading Sheldon's version...
# Do you want to see the instructions? Type yes or no : no
# Enter "Rock","Paper","Scissors","Lizard","Spock" to play
# Enter "exit" to quit
# --------------------------------------
# Enter your move :  Spock
# Computer making a move...
# Computer chooses... Spock
#
# IT'S A TIE!
# Do you want to see the instructions? Type yes or no : Lizard
# Do you want to see the instructions? Type yes or no : no
# Enter "Rock","Paper","Scissors","Lizard","Spock" to play
# Enter "exit" to quit
# --------------------------------------
# Enter your move :  Lizard
# Computer making a move...
# Computer chooses... Rock
#
# COMPUTER WINS
# Do you want to see the instructions? Type yes or no : Paper
# Do you want to see the instructions? Type yes or no : no
# Enter "Rock","Paper","Scissors","Lizard","Spock" to play
# Enter "exit" to quit
# --------------------------------------
# Enter your move :  lizard
# Computer making a move...
# Computer chooses... Rock
#
# COMPUTER WINS
# Do you want to see the instructions? Type yes or no : yes
# Loading instructions...
# You have to choose from:
# Enter 0 to choose Traditional version
# Enter 73 to choose Sheldon Cooper's version
#
#
#  How does it work?
#
#
#
#  Scissors cuts Paper
#  Paper covers Rock
#  Rock crushes Lizard
#  Lizard poisons Spock
#  Spock smashes Scissors
#  Scissors decapitates Lizard
#  Lizard eats Paper
#  Paper disproves Spock
#  Spock vaporizes Rock
#  Rock crushes Scissors
# Enter "Rock","Paper","Scissors","Lizard","Spock" to play
# Enter "exit" to quit
# --------------------------------------
# Enter your move :  rock
# Computer making a move...
# Computer chooses... Scissor
#
# PLAYER WINS
# Do you want to see the instructions? Type yes or no : paper
# Do you want to see the instructions? Type yes or no : no
# Enter "Rock","Paper","Scissors","Lizard","Spock" to play
# Enter "exit" to quit
# --------------------------------------
# Enter your move :  paper
# Computer making a move...
# Computer chooses... Scissor
#
# COMPUTER WINS
# Do you want to see the instructions? Type yes or no : scissors
# Do you want to see the instructions? Type yes or no : no
# Enter "Rock","Paper","Scissors","Lizard","Spock" to play
# Enter "exit" to quit
# --------------------------------------
# Enter your move :  scissors
# Computer making a move...
# Computer chooses... Paper
#
# PLAYER WINS
# Do you want to see the instructions? Type yes or no : no
# Enter "Rock","Paper","Scissors","Lizard","Spock" to play
# Enter "exit" to quit
# --------------------------------------
# Enter your move :  spock
# Computer making a move...
# Computer chooses... Lizard
#
# COMPUTER WINS
# Do you want to see the instructions? Type yes or no : rock
# Do you want to see the instructions? Type yes or no : no
# Enter "Rock","Paper","Scissors","Lizard","Spock" to play
# Enter "exit" to quit
# --------------------------------------
# Enter your move :  paper
# Computer making a move...
# Computer chooses... Spock
#
# PLAYER WINS
# Do you want to see the instructions? Type yes or no : paper
# Do you want to see the instructions? Type yes or no : np
# Do you want to see the instructions? Type yes or no : no
# Enter "Rock","Paper","Scissors","Lizard","Spock" to play
# Enter "exit" to quit
# --------------------------------------
# Enter your move :  paper
# Computer making a move...
# Computer chooses... Scissor
#
# COMPUTER WINS
# Do you want to see the instructions? Type yes or no : paper
# Do you want to see the instructions? Type yes or no : no
# Enter "Rock","Paper","Scissors","Lizard","Spock" to play
# Enter "exit" to quit
# --------------------------------------
# Enter your move :  paper
# Computer making a move...
# Computer chooses... Rock
#
# PLAYER WINS
# Do you want to see the instructions? Type yes or no : no
